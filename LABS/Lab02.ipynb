# %%
first = input()
second = input()

if((len(first)<=10) and (len(second)<=10)):
  print("Your input is valid. Press any key and then press enter to continue!!!")

  mul_arr = [[""]*10,[""]*10]
  for i in range(len(first)):
    mul_arr[0][i] = first[i]
  for i in range(len(second)):
    mul_arr[1][i] = second[i]

  for i in range(10):
    if(mul_arr[0][i]>="A" and mul_arr[0][i]<="Z"):
      f_start=mul_arr[0][i]
      f_index = i
  for i in range(10):
    if(mul_arr[1][i]>="A" and mul_arr[1][i]<="Z"):
      s_start=mul_arr[1][i]
      s_index = i

  print(f"Top Board Start Character: {f_start}")
  print(f"Top Board Start Index: {f_index}")
  print(f"Bottom Board Start Character: {s_start}")
  print(f"Bottom Board Start Index: {s_index}")

  

  while(True):
    print("Press any key and then press enter to continue!!!")
    inp = input()
    temp_first = f_index
    temp_second = s_index

    if(inp=="Q" or inp=="q"):

      for i in range(10):
        if(ord(mul_arr[0][i])>=65 and ord(mul_arr[0][i])<=90):
          f_start=mul_arr[0][i]
          f_index = i
      for i in range(10):
        if(ord(mul_arr[1][i])>=65 and ord(mul_arr[1][i])<=90):
          s_start=mul_arr[1][i]
          s_index = i
      print(f"Top Board Start Character: {f_start}")
      print(f"Top Board Start Index: {f_index}")
      print(f"Bottom Board Start Character: {s_start}")
      print(f"Bottom Board Start Index: {s_index}")

      break

    else:
      for i in range(10):
        print(mul_arr[0][temp_first],end="")
        temp_first -=1
        if(temp_first==-1):
          temp_first=10-1
      print()
      for i in range(10):
        print(mul_arr[1][temp_second],end="")
        temp_second = (temp_second+1)%10
      print()

      f_index-=1
      

      if(f_index==-1):
        f_index=10-1
      s_index = (s_index+1)%10


else:
  print("Invalid input size")
# Out:
# giRtfel2th
# rightLeft2
# Your input is valid. Press any key and then press enter to continue!!!
# Top Board Start Character: R
# Top Board Start Index: 2
# Bottom Board Start Character: L
# Bottom Board Start Index: 5
# Press any key and then press enter to continue!!!
# a
# Right2left
# Left2right
# Press any key and then press enter to continue!!!
# d
# ight2leftR
# eft2rightL
# Press any key and then press enter to continue!!!
# f
# ght2leftRi
# ft2rightLe
# Press any key and then press enter to continue!!!
# g
# ht2leftRig
# t2rightLef
# Press any key and then press enter to continue!!!
# h
# t2leftRigh
# 2rightLeft
# Press any key and then press enter to continue!!!
# r
# 2leftRight
# rightLeft2
# Press any key and then press enter to continue!!!
# p
# leftRight2
# ightLeft2r
# Press any key and then press enter to continue!!!
# t
# eftRight2l
# ghtLeft2ri
# Press any key and then press enter to continue!!!
# q
# Top Board Start Character: R
# Top Board Start Index: 2
# ...
